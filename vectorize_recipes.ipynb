# %%
import numpy as np
import pandas as pd
from  sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score
from sets import Set

# %%
df = pd.read_json('train.json')

# %%
IRRELEVANT = ['grated', 
              'ground',
              'extra',
              'virgin',
              'chopped',
              'fresh',
              'large',
              'minced',
              'shredded',
              'extra-virgin',
              'sliced',
              'fine',
              'finely',
              'finely-chopped',
              'freshly',
              'low',
              'sodium',
              'low-fat',
              'sliced',
              'slices',
              'of',
              'a',
              'the',
              'all-purpose',
              'nonfat',
              'non-fat',
              'crumbles',
              'thawed',
              'squeezed']

# %%
def all_words(df):
    matrix = []
    for i in xrange(len(df)):
        row = df.iloc[i]
        cuisine = row['cuisine']
        _id = row['id']
        ingredients = row['ingredients']
        for ingredient in ingredients:
            matrix.append([_id, cuisine, ingredient])
    newdf = pd.DataFrame(matrix, columns=['id', 'cuisine', 'ingredient'])
    return newdf

def all_words_from_strs(df):
    matrix = []
    for i in xrange(len(df)):
        row = df.iloc[i]
        cuisine = row['cuisine']
        _id = row['id']
        ingredients = row['ingredients'].split()
        for ingredient in ingredients:
            matrix.append([_id, cuisine, ingredient])
    newdf = pd.DataFrame(matrix, columns=['id', 'cuisine', 'ingredient'])
    return newdf

def ingredient_concat(df):
    matrix = []
    for i in xrange(len(df)):
        row = df.iloc[i]
        cuisine = row['cuisine']
        _id = row['id']
        ingredients = row['ingredients']
        joined_ingredients = " ".join(ingredients)
        matrix.append([_id, cuisine, joined_ingredients])
    newdf = pd.DataFrame(matrix, columns=['id', 'cuisine', 'ingredients'])
    return newdf

def smush(x):
    ret = []
    for ingr in x:
        ingr = ingr.split()
        ingr = "".join(ingr) # Make each ingredient one 'word'
        ret.append(ingr) # Putting all ingredients together
    return " ".join(ret)

def ingredient_join(df):
    matrix = []
    for i in xrange(len(df)):
        row = df.iloc[i]
        cuisine = row['cuisine']
        _id = row['id']
        ingredients = row['ingredients']
        joined_ingredients = smush(ingredients)
        matrix.append([_id, cuisine, joined_ingredients])
    newdf = pd.DataFrame(matrix, columns=['id', 'cuisine', 'ingredients'])
    return newdf

def Xy(df):
    df = df.copy()
    df = remove_irrelevant_words(df, IRRELEVANT)
    my_vocab = high_enough_frequency(df, 0)
    df_mash = ingredient_join(df)
    #dfi = all_words(df)
    #ingredients = dfi['ingredient'].unique()
    #all_ingredients = ["".join(x.split()) for x in ingredients]
    #my_vocab = {x:i for i, x in enumerate(all_ingredients)}
    meh = CountVectorizer(vocabulary=my_vocab)
    #meh = CountVectorizer()
    df_mash = ingredient_join(df)
    matrix = df_mash['ingredients'].values
    sparse_matrix = meh.fit_transform(matrix)
    X = sparse_matrix
    y = df['cuisine'].values
    return X, y.astype(str), meh

def remove_irrelevant_words(df, irrelevant):
    def ingredient_scan(ingr_list):
        recipe_list = []
        for ingr_str in ingr_list:
            ingr_list = ingr_str.split()
            ingr_list = [x for x in ingr_list]
            new_list = [x.replace('-', '') for x in ingr_list if x not in irrelevant]
            new_str = " ".join(new_list)
            recipe_list.append(new_str)
            
        return recipe_list
    df.loc[:, 'ingredients'] =  df['ingredients'].apply(ingredient_scan)
    return df

def high_enough_frequency(df, N):
    dfi = all_words(df)
    countdict = dfi.groupby('ingredient')['ingredient'].count().to_dict()
    
    #construct vocabulary dictionary:
    ret = {}
    i=0
    for ingredient in countdict:
        if countdict[ingredient]>N:
            ret[ingredient] = i
            i += 1   
    #ret = {ingredient:i for i, ingredient in enumerate(countdict) if countdict[ingredient]>N}
    return ret

# %%
X, y, count_obj = Xy(df)

# %%
np.shape(X)
# Out:
# (39774, 6357)

# %%
clf = RandomForestClassifier(n_estimators=10)

# %% [markdown]
# Random Forest using *all* ~7000 ingredients (with words in IRRELEVANT removed):

# %%
scores = cross_val_score(clf, X.toarray(), y, cv=10)
print scores
# Out:
# [ 0.5272271   0.53463855  0.54216867  0.53227832  0.52562814  0.52728187
#   0.54101661  0.5327291   0.53576826  0.53642551]

# %% [markdown]
# Random Forest Feature importance (with words in IRRELEVANT removed):

# %%
clf = RandomForestClassifier(n_estimators=10)
clf.fit(X.toarray(), y)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0)

# %%
importances = clf.feature_importances_
sorted_indices = np.argsort(importances)[::-1]

# %%
items = count_obj.vocabulary_.items()
index_as_key = {i:vocab for vocab, i in count_obj.vocabulary_.items()}
N = 500
for i in sorted_indices[:N-1]:
    print index_as_key[i]
# Out:
# oliveoil
# parmesancheese
# sesameoil
# cilantro
# ginger
# limejuice
# soysauce
# salt
# cumin
# chilipowder
# turmeric
# avocado
# mozzarellacheese
# salsa
# sugar
# mirin
# eggs
# water
# garlic
# jalapenochilies
# butter
# onions
# fishsauce
# blackpepper
# corntortillas
# pepper
# lime
# garammasala
# allpurposeflour
# greenonions
# lemonjuice
# garliccloves
# vegetableoil
# ricevinegar
# buttermilk
# flourtortillas
# tumeric
# cajunseasoning
# cornstarch
# carrots
# parsley
# milk
# scallions
# unsaltedbutter
# currypowder
# coconutmilk
# basil
# cinnamon
# coriander
# bakingpowder
# sourcream
# cheddarcheese
# koshersalt
# shallots
# oil
# tomatoes
# cayennepepper
# basilleaves
# blackbeans
# drywhitewine
# lemon
# eggyolks
# bakingsoda
# greenbellpepper
# brownsugar
# potatoes
# driedoregano
# shrimp
# cucumber
# redbellpepper
# fetacheesecrumbles
# paprika
# cuminseed
# flour
# fetacheese
# honey
# thyme
# mint
# chickenbroth
# plainyogurt
# pecans
# oystersauce
# heavycream
# flatleafparsley
# vanillaextract
# lemongrass
# bayleaves
# whitesugar
# cookingspray
# celery
# driedthyme
# italianseasoning
# purpleonion
# onion
# nutmeg
# parmigianoreggianocheese
# canolaoil
# driedbasil
# basmatirice
# whitepepper
# seasalt
# eggwhites
# sake
# sesameseeds
# allspice
# peanutoil
# greenchilies
# bacon
# arboriorice
# mayonaise
# spaghetti
# redpepper
# wholemilk
# cilantroleaves
# hoisinsauce
# garlicpowder
# beef
# dicedtomatoes
# hotsauce
# couscous
# mushrooms
# chicken
# creoleseasoning
# ghee
# granulatedsugar
# tacoseasoning
# chickenstock
# bourbonwhiskey
# enchiladasauce
# bonelessskinlesschickenbreasts
# pork
# andouillesausage
# cinnamonsticks
# sweetpotatoes
# whippingcream
# montereyjackcheese
# worcestershiresauce
# dill
# raisins
# zucchini
# tomatopaste
# whitevinegar
# collardgreens
# dijonmustard
# crushedredpepper
# whiteonion
# blackeyedpeas
# orangejuice
# yellowonion
# peeledginger
# bayleaf
# shaoxingwine
# gingerroot
# redwinevinegar
# oregano
# orange
# lemonzest
# cardamom
# creamcheese
# warmwater
# powderedsugar
# grits
# darksoysauce
# bonelessskinlesschickenbreasthalves
# sweetenedcondensedmilk
# peaches
# chives
# chickenbreasts
# chinesefivespicepowder
# tacoseasoningmix
# balsamicvinegar
# gochujangbase
# ricenoodles
# coldwater
# cabbage
# cookingoil
# beansprouts
# plumtomatoes
# tomatillos
# cheese
# confectionerssugar
# sharpcheddarcheese
# greenchile
# celeryribs
# peanuts
# almonds
# toastedsesameoil
# mustardseeds
# redchilipeppers
# rice
# ketchup
# chickpeas
# coconut
# greekyogurt
# tortillachips
# curryleaves
# activedryyeast
# cornmeal
# lightsoysauce
# yoghurt
# clove
# spinach
# tomatosauce
# chilepepper
# leeks
# springonions
# yellowcornmeal
# russetpotatoes
# redpepperflakes
# cayenne
# corianderseeds
# rosemary
# pinenuts
# capers
# hotwater
# mediumshrimp
# chipotlesinadobo
# greenbeans
# longgrainrice
# cookedrice
# dashi
# cachaca
# ricottacheese
# szechwanpeppercorns
# coarsesalt
# whitewinevinegar
# saffronthreads
# sauce
# lightbrownsugar
# pastasauce
# sherryvinegar
# vanilla
# unsweetenedcoconutmilk
# asianfishsauce
# cidervinegar
# vinegar
# okra
# blackpeppercorns
# pasta
# limewedges
# evaporatedmilk
# bananas
# marinarasauce
# darkbrownsugar
# prosciutto
# lamb
# boilingwater
# crushedredpepperflakes
# onionpowder
# smokedpaprika
# refriedbeans
# eggplant
# bakingpotatoes
# meltedbutter
# thairedcurrypaste
# selfrisingflour
# kimchi
# beefbroth
# crackedblackpepper
# linguine
# shortening
# lettuce
# drysherry
# greenpepper
# margarine
# quesofresco
# half
# frozenpeas
# mascarpone
# sweetonion
# breadcrumbs
# bonelesschickenskinlessthigh
# staranise
# thaichile
# longgrainwhiterice
# darksesameoil
# corn
# whiterice
# quickcookinggrits
# unsweetenedcocoapowder
# firmtofu
# wholewheatflour
# redpotato
# redcurrypaste
# baguette
# hotpeppersauce
# strawberries
# yukongoldpotatoes
# bellpepper
# walnuts
# apples
# redwine
# mango
# waterchestnuts
# breadflour
# crawfish
# crèmefraîche
# toastedsesameseeds
# cloves
# goldenraisins
# masaharina
# driedapricot
# ham
# polenta
# bread
# lasagnanoodles
# mintleaves
# sweetchilisauce
# cornkernels
# partskimmozzarellacheese
# vanillabeans
# fatfreelesschickenbroth
# creamtartar
# applecidervinegar
# beer
# plainflour
# englishcucumber
# dryredwine
# chickenthighs
# vegetablebroth
# barbecuesauce
# pears
# cardamompods
# frenchbread
# cream
# sriracha
# almondextract
# yeast
# lemonwedge
# ricewine
# nori
# smokedsausage
# anchovyfillets
# radishes
# shiitake
# thymeleaves
# thaibasil
# brandy
# montereyjack
# napacabbage
# drybreadcrumbs
# frozenpastrypuffsheets
# cherrytomatoes
# whitewine
# garlicpaste
# lightcoconutmilk
# salmonfillets
# beets
# redchilipowder
# saffron
# thymesprigs
# pecorinoromanocheese
# chiles
# fennelseeds
# cakeflour
# cauliflower
# gruyerecheese
# orangezest
# greencabbage
# wontonwrappers
# lemonpeel
# pineapple
# icewater
# fettucine
# pimentos
# swisscheese
# palmsugar
# leanbeef
# peas
# sliveredalmonds
# greentomatoes
# frozencorn
# heavywhippingcream
# porktenderloin
# meat
# crushedtomatoes
# lard
# tequila
# provolonecheese
# tabascopeppersauce
# babyspinach
# greekstyleplainyogurt
# saltchickenbroth
# yellowbellpepper
# raspberries
# semisweetchocolate
# tarragon
# noodles
# pittedkalamataolives
# kalamata
# sausages
# misopaste
# vegetableoilcookingspray
# lightcornsyrup
# chinesericewine
# spanishchorizo
# chorizosausage
# sage
# marsalawine
# jasminerice
# allpurposeunbleachedflour
# asparagus
# juice
# roastedpeanuts
# tortillas
# flanksteak
# bittersweetchocolate
# grannysmithapples
# castersugar
# whitecornmeal
# anchochilepepper
# greenpeas
# snowpeas
# blackolives
# coconutoil
# roastedredpeppers
# mussels
# mexicancheeseblend
# daikon
# sushirice
# saltandblackpepper
# condensedmilk
# carawayseeds
# olives
# serranochile
# drymustard
# vegetables
# lettuceleaves
# darkrum
# chili
# hazelnuts
# creamypeanutbutter
# greenolives
# romainelettuce
# sweetpaprika
# tapiocaflour
# pennepasta
# pecanhalves
# garbanzobeans
# chickenwings
# fennelbulb
# superfinesugar
# cognac
# vegetableshortening
# riceflour
# frozenspinach
# cornflour
# irishwhiskey
# purevanillaextract
# pancetta
# driedrosemary
# reducedfatmilk
# hardboiledegg
# porkbelly
# ice
# chiliflakes
# poblanochiles
# driedcurrants
# jackcheese
# rum
# mintsprigs
# corianderpowder
# thaifishsauce
# italiansausage
# chipotlechile
# kaffirlimeleaves
# breadcrumb
# seasoningsalt
# leglamb
# icecubes
# manchegocheese
# peanutbutter
# mozzarella
# seasoning
# teriyakisauce
# broccoliflorets
# orangepeel
# peppercorns
# instantyeast
# cilantrosprigs
# parsleyleaves
# beefstock
# maplesyrup
# coffee
# pankobreadcrumbs
# konbu
# marjoram
# cannellinibeans
# gruyèrecheese
# boilingpotatoes
# turkey
# herbs
# kale
# cookedwhiterice
# brownrice
# garlicchilisauce
# unflavoredgelatin
# arugula
# preservedlemon

# %%
dfi = all_words(df)

# %%
adict = dfi.groupby('ingredient')['ingredient'].count().to_dict()
newdict = {w}
# Out:
# {u'low-sodium fat-free chicken broth': 22,
#  u'sweetened coconut': 3,
#  u'baking chocolate': 3,
#  u'egg roll wrappers': 57,
#  u'bottled low sodium salsa': 1,
#  u'vegan parmesan cheese': 4,
#  u'clam sauce': 1,
#  u'(10 oz.) frozen chopped spinach, thawed and squeezed dry': 2,
#  u'figs': 33,
#  u'caramels': 10,
#  u'broiler': 2,
#  u'jalapeno chilies': 1730,
#  u'(15 oz.) refried beans': 3,
#  u'brioche buns': 3,
#  u'broccoli romanesco': 1,
#  u'flaked oats': 1,
#  u'anise extract': 14,
#  u'whole wheat pastry flour': 30,
#  u'ravva': 11,
#  u'bacon': 620,
#  u'millet': 5,
#  u'country crock honey spread': 1,
#  u'matcha green tea powder': 11,
#  u'chopped fresh thyme': 375,
#  u'chicken gravy mix': 2,
#  u'walnut oil': 14,
#  u'Kraft Slim Cut Mozzarella Cheese Slices': 1,
#  u'fresh angel hair': 5,
#  u'salsify': 2,
#  u'galangal': 85,
#  u'chicken schmaltz': 3,
#  u'butter crackers': 3,
#  u'jasmine': 6,
#  u'Bisquick Baking Mix': 8,
#  u'canned jalapeno peppers': 2,
#  u'black grapes': 1,
#  u'ground cayenne pepper': 139,
#  u'orange soda': 1,
#  u'chopmeat': 1,
#  u'calamansi juice': 17,
#  u'butter oil': 20,
#  u'steel-cut oats': 7,
#  u'chinese buns': 1,
#  u'boneless ham': 2,
#  u'chipotle sauce': 9,
#  u'honey dijon mustard': 2,
#  u'custard dessert mix': 1,
#  u'gluten-free broth': 1,
#  u'thai noodles': 10,
#  u'ancho chile pepper': 143,
#  u'salted fish': 5,
#  u'yellow mustard seeds': 35,
#  u'yellow split peas': 26,
#  u'spaghetti sauce seasoning mix': 3,
#  u'sweet mustard': 2,
#  u'burger style crumbles': 1,
#  u'Taco Bell Taco Seasoning Mix': 4,
#  u'yellow squash': 116,
#  u'bean sauce': 17,
#  u'Martha White Cornbread Mix': 1,
#  u'Toulouse sausage': 1,
#  u'egg roll skins': 1,
#  u'lemon thyme': 3,
#  u'whole peppercorn': 21,
#  u'fat free greek yogurt': 10,
#  u'shirataki': 9,
#  u'cooked vegetables': 1,
#  u'wheat bran': 8,
#  u'mild sausage': 1,
#  u'chocolate sauce': 9,
#  u'green beans': 341,
#  u'vegetarian protein crumbles': 1,
#  u'chicken breast strips': 5,
#  u'Bertolli Tomato & Basil Sauce': 1,
#  u'raw pistachios': 4,
#  u'duck drumsticks': 16,
#  u'pompano fillets': 2,
#  u'white creme de cacao': 1,
#  u'Jarlsberg': 4,
#  u'gluten flour': 1,
#  u'sliced black olives': 161,
#  u'nonfat dry milk': 9,
#  u'dried neem leaves': 1,
#  u'duck bones': 1,
#  u'chocolate morsels': 21,
#  u'maple extract': 3,
#  u'minced pork': 36,
#  u'jaggery': 40,
#  u'nonfat ricotta cheese': 35,
#  u'arrowroot powder': 14,
#  u'coconut flakes': 21,
#  u'rum extract': 3,
#  u'cane vinegar': 10,
#  u'wine': 57,
#  u'dried sardines': 2,
#  u'frying oil': 6,
#  u'balsamic vinaigrette salad dressing': 2,
#  u'roquefort': 2,
#  u'baby carrots': 72,
#  u'Bartlett Pear': 2,
#  u'radish sprouts': 8,
#  u'sour mix': 2,
#  u'yellowfin': 1,
#  u'beef stew seasoning mix': 1,
#  u'aleppo': 1,
#  u'plantains': 38,
#  u'pickling liquid': 2,
#  u'tea leaves': 3,
#  u'Robert Mondavi Fume Blanc': 1,
#  u'red food coloring': 71,
#  u'fennel bulb': 205,
#  u'cool whip': 12,
#  u'treviso': 1,
#  u'silver': 7,
#  u'gluten-free tamari sauce': 1,
#  u'moroccan seasoning': 2,
#  u'thyme': 361,
#  u'green leaf lettuce': 31,
#  u'buckwheat groats': 2,
#  u'chocolate chunks': 2,
#  u'apricot jam': 21,
#  u'yam bean': 1,
#  u'red pepper hot sauce': 2,
#  u'cola-flavored carbonated beverage': 1,
#  u'fat free cream of mushroom soup': 1,
#  u'Old El Paso Flour Tortillas': 5,
#  u'unsalted shelled pistachio': 4,
#  u'cooking spray': 1490,
#  u'fettuccine pasta': 30,
#  u'prune juice': 1,
#  u'nuoc cham': 9,
#  u'jamaican jerk rub': 1,
#  u'pomegranate seeds': 29,
#  u'McCormick Ground Ginger': 2,
#  u'shredded Italian cheese': 7,
#  u'nam pla': 8,
#  u'oyster mushrooms': 33,
#  u'curry mix': 1,
#  u'soft corn tortillas': 7,
#  u'snail shells': 4,
#  u'japanese eggplants': 53,
#  u'fresh brussels sprouts': 2,
#  u'low sodium beef stock': 8,
#  u'toasted almonds': 39,
#  u'tzatziki': 17,
#  u'peasant bread': 9,
#  u'shredded pepper jack cheese': 31,
#  u'andouille turkey sausages': 2,
#  u'salt water': 2,
#  u'pickling salt': 12,
#  u'crab sticks': 1,
#  u'Morton Salt': 2,
#  u'oil-cured black olives': 21,
#  u'pink lady apple': 2,
#  u'process cheese spread': 2,
#  u'freshly grated parmesan': 105,
#  u'cornflour': 103,
#  u'crusty whole wheat toast': 1,
#  u'chopped fresh sage': 123,
#  u'beef shank': 34,
#  u'wheat bread': 7,
#  u'japanese rice': 19,
#  u'red curry paste': 122,
#  u'idli': 5,
#  u'Crystal Farms Shredded Gouda Cheese': 1,
#  u'sweet chocolate': 3,
#  u'lemon juice': 1395,
#  u'Country Crock\xae Spread': 21,
#  u'asian black bean sauce': 1,
#  u'canola oil cooking spray': 2,
#  u'chunky mild salsa': 3,
#  u'icing mix': 1,
#  u'bread flour': 193,
#  u"Cox's Orange Pippin": 1,
#  u'artichoke hearts': 135,
#  u'dark miso': 2,
#  u'kangkong': 3,
#  u'flank steak': 258,
#  u'Kewpie Mayonnaise': 6,
#  u'hollandaise sauce': 4,
#  u'chocolate instant pudding': 10,
#  u'poppy seed dressing': 2,
#  u'reduced sugar orange marmalade': 2,
#  u'dried mixed herbs': 9,
#  u'Pillsbury\u2122 Crescent Recipe Creations\xae refrigerated seamless dough sheet': 1,
#  u'extra large shrimp': 19,
#  u'taco bell home originals': 5,
#  u'fresh tofu': 2,
#  u'rocket leaves': 49,
#  u'tequila': 133,
#  u'Flora pro.activ': 1,
#  u'fennel': 77,
#  u'california chile': 4,
#  u'whole grain buns': 1,
#  u'pecan meal': 1,
#  u'chaat masala': 45,
#  u'lipton tea bags': 2,
#  u'vegan margarine': 6,
#  u'methi leaves': 4,
#  u'raspberry lambic': 1,
#  u'filo dough': 4,
#  u'napa cabbage leaves': 17,
#  u'grated orange peel': 95,
#  u'red drum': 1,
#  u'codfish': 3,
#  u'fresh orange juice': 209,
#  u'fresno pepper': 1,
#  u'Land O Lakes\xae Butter': 2,
#  u'chocolate syrup': 15,
#  u'sweet italian sausag links, cut into': 4,
#  u'citrus juice': 2,
#  u'cherry vinegar': 1,
#  u'chutney': 53,
#  u'Smithfield Ham': 3,
#  u'spanish rice': 9,
#  u'greens': 96,
#  u'Accent Seasoning': 6,
#  u'chinese celery cabbage': 1,
#  u'dry fettuccine': 1,
#  u'cooked bone in ham': 4,
#  u'aged cheddar cheese': 3,
#  u'earl grey tea bags': 3,
#  u'laurel leaves': 4,
#  u'Velveeta': 30,
#  u'lacinato kale': 10,
#  u'spareribs': 14,
#  u'whipped butter': 2,
#  u'cuttlefish balls': 2,
#  u'low fat reduced sodium pasta sauce': 1,
#  u'ciabatta buns': 1,
#  u'knorr leek recip mix': 3,
#  u'dark chicken stock': 1,
#  u'Bertolli\xae Alfredo Sauce': 8,
#  u'capocollo': 3,
#  u'melissa': 1,
#  u'cooked turkey': 48,
#  u'dark turkey meat': 1,
#  u'wish bone ranch dress': 3,
#  u'claws': 1,
#  u'fresh tomato salsa': 13,
#  u'mentaiko': 1,
#  u'low sodium crushed tomatoes': 2,
#  u'Neufch\xe2tel': 6,
#  u'japanese style bread crumbs': 1,
#  u'mahimahi': 6,
#  u'barbecue sauce': 126,
#  u'orange segments': 3,
#  u'uncooked ziti': 6,
#  u'kirschwasser': 2,
#  u'barley miso': 2,
#  u'crumbled gorgonzola': 37,
#  u'sweet soy': 1,
#  u'sourdough rolls': 1,
#  u'low fat mozzarella': 11,
#  u'raita': 9,
#  u'nonfat half-and-half': 1,
#  u'dhal': 11,
#  u'canned beef broth': 25,
#  u'ox tongue': 2,
#  u'spring roll skins': 4,
#  u'mizuna': 3,
#  u'sauterne': 6,
#  u'sorghum molasses': 1,
#  u'salt free southwest chipotle seasoning': 2,
#  u'horseradish': 45,
#  u'gyoza': 13,
#  u'instant oats': 1,
#  u'grated lemon peel': 181,
#  u'chili bean sauce': 17,
#  u'soft shelled crabs': 6,
#  u'barilla piccolini mini': 1,
#  u'chili': 187,
#  u'light beer': 14,
#  u'ground nuts': 1,
#  u'b\xe2tarde': 1,
#  u'hog casings': 5,
#  u'chopped almonds': 47,
#  u'chestnut spread': 1,
#  u'celery ribs': 567,
#  u'solid white tuna': 5,
#  u'curry leaf': 4,
#  u'granulated white sugar': 21,
#  u'pot roast': 5,
#  u'loin pork chops': 6,
#  u'jamaican rum': 5,
#  u'short rib': 28,
#  u'pickapeppa sauce': 4,
#  u'ragu cheesi classic alfredo sauc': 5,
#  u'beef base': 6,
#  u'tuna': 44,
#  u'chicken breast tenders': 29,
#  u'no-calorie sweetener': 1,
#  u'carnitas': 10,
#  u'medium dry sherry': 28,
#  u'burgers': 5,
#  u'fideos': 6,
#  u'fine salt': 24,
#  u'whole grain bread': 6,
#  u'yellow curry paste': 11,
#  u'praline syrup': 1,
#  u'burro banana': 1,
#  u'Italian seasoned diced tomatoes': 1,
#  u'asian wheat noodles': 2,
#  u'large flour tortillas': 19,
#  u'microgreens': 2,
#  u'alum': 2,
#  u'ham': 222,
#  u'marshmallow vodka': 1,
#  u'frozen chopped spinach': 206,
#  u'roast beef': 18,
#  u'low-fat milk': 44,
#  u'flat cut': 2,
#  u'acorn squash': 18,
#  u'egg beaters': 1,
#  u'ampalaya': 3,
#  u'soft margarine': 1,
#  u'english walnuts': 1,
#  u'umeboshi': 3,
#  u'color food green': 17,
#  u'smoked mackerel': 1,
#  u'grated jack cheese': 60,
#  u'fresh pasta': 7,
#  u'dende oil': 7,
#  u'hot spanish paprika': 2,
#  u'meringue': 9,
#  u'black peppercorns': 453,
#  u'asakusa nori': 1,
#  u'fat-trimmed beef flank steak': 1,
#  u'breakfast sausages': 30,
#  u'shanghai noodles': 3,
#  u'small new potatoes': 12,
#  u'boiling potatoes': 99,
#  u'okra': 268,
#  u'Honeysuckle White\xae Hot Italian Turkey Sausage Links': 1,
#  u'arborio rice': 292,
#  u'root beer': 1,
#  u'borage': 2,
#  u'Hidden Valley\xae Original Ranch Salad\xae Dressing & Seasoning Mix': 2,
#  u'sub buns': 8,
#  u'fruit juice': 1,
#  u'buttermilk self-rising white cornmeal mix': 1,
#  u'low fat mild Italian turkey sausage': 1,
#  u'flatbread': 27,
#  u'smoked pork': 4,
#  u'mochi': 2,
#  u'cooked steak': 2,
#  u'baking sugar': 1,
#  u'homemade stock': 1,
#  u'soy': 12,
#  u'goat milk feta': 1,
#  u'japanese peanuts': 1,
#  u'shrimp paste': 56,
#  u'ground almonds': 50,
#  u'filipino eggplant': 1,
#  u'flat anchovy': 7,
#  u'dried prawns': 1,
#  u'dried cascabel chile': 2,
#  u'Velveeta Queso Blanco': 1,
#  u'white onion': 684,
#  u'quatre \xe9pices': 4,
#  u'Southern Comfort Liqueur': 2,
#  u'curly kale': 9,
#  u'candied pineapple': 2,
#  u'do chua': 1,
#  u'panettone': 6,
#  u'reduced sodium reduced fat cream of mushroom soup': 1,
#  u'mushroom caps': 39,
#  u'panela': 1,
#  u'paprika': 1287,
#  u'low sodium low fat vegetable broth': 1,
#  u'tuna steaks': 40,
#  u'diced onions': 242,
#  u'free range chicken breasts': 2,
#  u'butter salt': 1,
#  u'falafel': 1,
#  u'sunflower seeds': 14,
#  u'kha': 1,
#  u'Angostura bitters': 13,
#  u'gram dal': 2,
#  u'whipped cream': 103,
#  u'truffles': 5,
#  u'Heinz Tomato Ketchup': 1,
#  u'shaved parmesan cheese': 8,
#  u'new mexico chile pods': 1,
#  u'minced garlic': 1583,
#  u'bottled lime juice': 2,
#  u'annatto powder': 3,
#  u'ground poppy seed': 1,
#  u'sweet potato vermicelli': 3,
#  u'pot pie': 1,
#  u'Chinese egg noodles': 44,
#  u'flour tortillas (not low fat)': 4,
#  u'Madeira': 33,
#  u'strip loin': 1,
#  u'pork cutlets': 11,
#  u'steak fillets': 2,
#  u'samphire': 1,
#  u'candied orange peel': 27,
#  u'duck breasts': 21,
#  u'Crystal Farms\xae Shredded Cheddar Cheese': 1,
#  u'extra large eggs': 32,
#  u'skate': 3,
#  u'conchiglie': 1,
#  u'stevia powder': 2,
#  u'green chard': 2,
#  u'softened butter': 49,
#  u'lavender honey': 1,
#  u'mixed vegetables': 22,
#  u'blanched almonds': 93,
#  u'icing': 7,
#  u'chilli bean sauce': 2,
#  u'lard': 157,
#  u'lemon pudding': 1,
#  u'skate wing': 2,
#  u'farro': 21,
#  u'mooli': 1,
#  u'buckwheat honey': 1,
#  u'chicken pan drippings': 1,
#  u'tangerine juice': 10,
#  u'teas': 37,
#  u'Ni\xe7oise olives': 27,
#  u'green grape': 7,
#  u'dried porcini mushrooms': 100,
#  u'oil packed dried tomatoes': 2,
#  u'havarti cheese': 8,
#  u'sloe gin': 1,
#  u'crab meat': 33,
#  u'bay leaves': 1036,
#  u'orange blossom honey': 11,
#  u'breasts halves': 2,
#  u'smoked hog jowl': 1,
#  u'carne seca': 4,
#  u'condensed tomato soup': 17,
#  u'33% less sodium ham': 3,
#  u'water chestnuts, drained and chopped': 10,
#  u'celery root': 34,
#  u'vanilla instant pudding': 30,
#  u'crumbles': 11,
#  u'chicken base': 15,
#  u'pasta shells': 30,
#  u'cream of chicken soup': 83,
#  u'old-fashioned oats': 14,
#  u'fresno chiles': 13,
#  u'marrons': 1,
#  u'beef for stew': 5,
#  u'Wish-Bone\xae Robusto Italian Dressing': 1,
#  u'sumac powder': 1,
#  u'Argo Corn Starch': 1,
#  u'cream sweeten whip': 39,
#  u'pork leg': 6,
#  u'bacon fat': 23,
#  u'flounder fillets': 11,
#  u'snow pea pods': 2,
#  u'low-fat flour tortillas': 3,
#  u'papad': 4,
#  u'refrigerated chocolate chip cookie dough': 1,
#  u'butternut squash': 174,
#  u'asparagus tips': 6,
#  u'lamb shanks': 48,
#  u'leg of lamb': 89,
#  u'anasazi beans': 2,
#  u'teleme': 2,
#  u'frozen whole kernel corn': 84,
#  u'spearmint': 6,
#  u'cola soft drink': 4,
#  u'dark beer': 12,
#  u'tostitos': 2,
#  u'chinese leaf': 4,
#  u'baby spinach leaves': 103,
#  u'tiger prawn': 25,
#  u'powdered milk': 31,
#  u'salted seaweed': 1,
#  u'hot Italian sausages': 48,
#  u'chocolate covered english toffee': 3,
#  u'pie shell': 32,
#  u'fleur de sel': 25,
#  u'unbaked pie crusts': 17,
#  u'Lipton Lemon Iced Tea Mix': 1,
#  u'italian eggplant': 10,
#  u'guanciale': 21,
#  u'lamb shoulder': 84,
#  u'snaps': 1,
#  u'cubed pumpkin': 2,
#  u'Knorr Onion Minicubes': 3,
#  u'yellow mustard': 47,
#  u'Irish Red ale': 2,
#  u'phyllo pastry': 36,
#  u'katsuo dashi': 1,
#  u'teriyaki marinade': 2,
#  u'veal for stew': 7,
#  u'mango': 268,
#  u'chinese wolfberries': 1,
#  u'pork tongue': 2,
#  u'masa harina': 100,
#  u'ground blanched almonds': 4,
#  u'oat bran': 4,
#  u'pink grapefruit juice': 5,
#  u'green tea leaves': 3,
#  u'thai green curry paste': 50,
#  u'dillweed': 2,
#  u'reduced sodium beef broth': 14,
#  u'imitation seafood': 1,
#  u'red bell pepper': 1939,
#  u'powdered sugar icing': 1,
#  u'red enchilada sauce': 65,
#  u'ketchup': 432,
#  u'caramel ice cream topping': 4,
#  u'Mazola Canola Oil': 1,
#  u'wagon wheels': 1,
#  u'arrowroot flour': 2,
#  u'albacore tuna in water': 7,
#  u'instant chicken bouillon granules': 1,
#  u'waffle fries': 1,
#  u'cooked brisket': 2,
#  u'turtle': 1,
#  u'mellow white miso': 1,
#  u'fish fillets': 77,
#  u'amaretto': 28,
#  u'bottom round roast': 2,
#  u'amaretti': 7,
#  u'whipping heavy cream': 5,
#  u'savoy cabbage': 55,
#  u'center-cut salmon fillet': 2,
#  u'linguini': 11,
#  u'hoagie buns': 3,
#  u'orange marmalade': 42,
#  u'linguine': 248,
#  u'agave nectar': 81,
#  u'medium cheddar cheese': 1,
#  u'dulong': 1,
#  u'mini phyllo dough shells': 4,
#  u'coconut oil': 221,
#  u'cabbage leaves': 12,
#  u'jasmine rice': 152,
#  u'sweet pepper': 62,
#  u'green papaya': 26,
#  u'red swiss chard': 5,
#  u'date sugar': 1,
#  u'frozen garden peas': 1,
#  u'boneless skin on chicken thighs': 4,
#  u'smoked paprika': 345,
#  u'pasta wagon wheel': 1,
#  u'wish bone red wine vinaigrett dress': 1,
#  u'ground sausage': 10,
#  u'low fat cream': 3,
#  u'malted milk powder': 1,
#  u'large egg yolks': 575,
#  u'low sodium canned chicken stock': 5,
#  u'chocolate milk mix': 1,
#  u'hot smoked paprika': 13,
#  u'old bay seasoning': 98,
#  u'ascorbic acid': 1,
#  u'nonfat buttermilk': 14,
#  u'dark chocolate': 41,
#  u'Success White Rice': 1,
#  u'(   oz.) tomato paste': 9,
#  u'salmon steaks': 13,
#  u'brown gravy': 2,
#  u'frozen lima beans': 4,
#  u'aleppo pepper': 12,
#  u'low-fat sour cream': 62,
#  u'toasted nuts': 1,
#  u'iceberg': 4,
#  u'pitted black olives': 47,
#  u'gluten-free breadcrumbs': 2,
#  u'breadstick': 15,
#  u'whole wheat lasagna noodles': 8,
#  u'green lentil': 18,
#  u'madeira wine': 3,
#  u'herb dressing': 1,
#  u'ammonium bicarbonate': 1,
#  u'turkey broth': 6,
#  u'Sangiovese': 1,
#  u'Sargento\xae Traditional Cut Shredded 4 Cheese Mexican': 2,
#  u'whole garam masala': 1,
#  u'red pepper': 459,
#  u'italian pork sausage': 7,
#  u'vegetable demi-glace': 3,
#  u'coconut cream': 77,
#  u'chicken wingettes': 2,
#  u'low-fat feta': 1,
#  u'havarti': 1,
#  u'braggs liquid aminos': 1,
#  u'strawberry preserves': 5,
#  u'stewing beef': 23,
#  u'KRAFT Mexican Style Finely Shredded Four Cheese': 5,
#  u'carnaroli rice': 14,
#  u'apple pie spice': 4,
#  u'deviled ham': 1,
#  u'crushed red pepper': 825,
#  u'parmigiano-reggiano cheese': 61,
#  u'lemon slices': 70,
#  u'oloroso sherry': 5,
#  u'passion fruit juice': 4,
#  u'salt': 18049,
#  u'royal olives': 1,
#  u'banger': 7,
#  u'Lipton Sparkling Diet Green Tea with Strawberry Kiwi': 1,
#  u'sesame oil': 1773,
#  u'flowering chives': 4,
#  u'calamari': 16,
#  u'gluten free corn tortillas': 3,
#  u'key lime': 7,
#  u'Jamaican allspice': 4,
#  u'raspberry sauce': 4,
#  u'Mexican oregano': 100,
#  u'egg roll wraps': 4,
#  u'frozen sweet peas': 7,
#  u'wholemeal flour': 5,
#  u'tofu puffs': 2,
#  u'corn oil': 121,
#  u'nori flakes': 2,
#  u'brown rice spaghetti': 1,
#  u'duck sauce': 1,
#  u'shredded romano cheese': 2,
#  u'dried rigatoni': 1,
#  u'Neapolitan ice cream': 1,
#  u'chopped green chilies': 58,
#  u'bean curd': 10,
#  u'ginger piece': 7,
#  u'blade steak': 2,
#  u'eye of round steak': 3,
#  u'minute steaks': 1,
#  u'single malt Scotch': 1,
#  u'garlic pepper blend': 1,
#  u'sweet potato starch': 3,
#  u'mutton': 24,
#  u'cornflake cereal': 10,
#  u'pea pods': 12,
#  u'cauliflower flowerets': 3,
#  u'sourdough starter': 4,
#  u'2% low fat cheddar chees': 1,
#  u'calvados': 21,
#  u'edamame': 51,
#  u'cantaloupe': 24,
#  u'vegan butter': 9,
#  u'bosc pears': 23,
#  u'snow peas': 183,
#  u'shrimp tails': 8,
#  u'Yoplait\xae Greek 100 blackberry pie yogurt': 1,
#  u'pickled jalapenos': 27,
#  u'cole slaw mix': 2,
#  u'hot bean paste': 9,
#  u'asti spumante': 1,
#  u'tamarind juice': 16,
#  u'extra-virgin olive oil': 2747,
#  u'sodium reduced chicken broth': 1,
#  u'vital wheat gluten': 2,
#  u'chorizo': 68,
#  u'low-fat cottage cheese': 19,
#  u'lamb cutlet': 3,
#  u'maldon sea salt': 8,
#  u'ice water': 164,
#  u'tortellini, cook and drain': 2,
#  u'french style sandwich rolls': 1,
#  u'tuna in oil': 3,
#  u'black walnut': 2,
#  u'vegan yogurt': 1,
#  u'boar': 5,
#  u'cura\xe7ao': 3,
#  u'hot sausage': 3,
#  u'red quinoa': 1,
#  u'sherry vinegar': 160,
#  u'unsweetened vanilla almond milk': 1,
#  u'prosciutto fat': 1,
#  u'artichokes': 75,
#  u'Mizkan Oigatsuo Tsuyu Soup Base': 2,
#  u'nigella seeds': 24,
#  u'cake mix': 6,
#  u'fresh flounder fillets': 1,
#  u'roasted cashews': 37,
#  u'sablefish': 1,
#  u'artichok heart marin': 51,
#  u'prepar salsa': 30,
#  u'caramel ice cream': 2,
#  u'macaroni and cheese dinner': 1,
#  u'white button mushrooms': 27,
#  u'Massaman curry paste': 6,
#  u'agar agar flakes': 1,
#  u'red kidney beans': 95,
#  u'thyme leaves': 41,
#  u'steel-cut oatmeal': 2,
#  u'gluten-free tamari': 6,
#  u'elbow macaroni': 90,
#  u'sandwich bread': 5,
#  u'cooking sherry': 18,
#  u'sliced salami': 4,
#  u'twists': 5,
#  u'frozen lemonade concentrate': 12,
#  u'side pork': 1,
#  u'red beets': 11,
#  u'compressed yeast': 3,
#  u'Knorr\xae Beef Bouillon': 1,
#  u'fresh lime': 29,
#  u'cake mix or white yellow': 1,
#  u'sucralose sweetener': 1,
#  u'chopped celery': 426,
#  u'Soy Vay\xae Hoisin Garlic Marinade & Sauce': 1,
#  u'karo syrup': 2,
#  u'poultry seasoning': 62,
#  u'caponata': 1,
#  u'dinosaur kale': 1,
#  u'gumbo file powder': 2,
#  u'remoulade': 3,
#  u'Elmlea single': 1,
#  u'spaghetti, cook and drain': 8,
#  u'veal': 31,
#  u'peach nectar': 17,
#  u'Lipton\xae Recipe Secrets\xae Onion Soup Mix': 3,
#  u'dr. pepper': 2,
#  u'adzuki beans': 5,
#  u'bacon rind': 1,
#  u'raw cane sugar': 5,
#  u'steamer': 10,
#  u'cilantro': 1142,
#  u'fromage blanc': 6,
#  u'coffee beans': 17,
#  u'Barilla Oven-Ready Lasagne': 2,
#  u'Tabasco Pepper Sauce': 184,
#  u'double crust': 1,
#  u'endive': 3,
#  u'rice milk': 1,
#  u'lemon dressing': 2,
#  u'pork spareribs': 25,
#  u'jerk sauce': 6,
#  u'whole wheat berries': 1,
#  u'crostini': 6,
#  u'turkey breast deli meat': 2,
#  u'nondairy whipped topping': 1,
#  u'strawberry gelatin': 1,
#  u'pumpkin pie spice': 22,
#  u'nonstick spray': 50,
#  u'chicken chorizo sausages': 1,
#  u'breadfruit': 2,
#  u'anise seed': 54,
#  u'poi': 1,
#  u'tvp': 2,
#  u'clementine juice': 1,
#  u'lobster': 50,
#  u'reduced fat ricotta cheese': 2,
#  u'pork blood': 5,
#  u'pickles': 36,
#  u'frozen limeade': 7,
#  u'lemon soda': 1,
#  u'reduced-fat sour cream': 105,
#  u'zest': 10,
#  u'ground fennel': 19,
#  u'onion salt': 15,
#  u'low sodium tomato sauce': 3,
#  u'yoghurt natural low fat': 1,
#  u'piloncillo': 22,
#  u'barley flour': 4,
#  u'sliced mango': 1,
#  u'prepared guacamole': 6,
#  u'La Victoria Red Chile Sauce': 1,
#  u'dark rum': 116,
#  u'ripe olives': 92,
#  u'table syrup': 1,
#  u'fermented black beans': 36,
#  u'low sodium store bought chicken stock': 4,
#  u'pak choi': 10,
#  u'vegetarian chicken': 1,
#  u'pastry cream': 7,
#  u'asian pear': 44,
#  u'rub seasoning': 1,
#  u'low-fat canned coconut milk': 1,
#  u'buttercup squash': 1,
#  u'quickcooking grits': 86,
#  u'bone in skin on chicken thigh': 18,
#  u'tahini paste': 3,
#  u'chicharron': 1,
#  u'hen': 1,
#  u'fideos pasta': 1,
#  u'carne asada': 3,
#  u'cake batter': 4,
#  u'ground sichuan pepper': 17,
#  u'laksa paste': 1,
#  u'red potato': 205,
#  u'rusk': 1,
#  u'chicken and rice soup': 1,
#  u'Sicilian olives': 7,
#  u'tripe': 7,
#  u'cipollini': 1,
#  u'ragu': 8,
#  u'dri leav thyme': 35,
#  u'pinot blanc': 2,
#  u'shredded cabbage': 111,
#  u'spaghettini': 24,
#  u'sea scallops': 114,
#  u'nacho cheese tortilla chips': 1,
#  u'cream': 258,
#  u'coffee ice cream': 7,
#  u'curry powder': 694,
#  u'tagliatelle': 21,
#  u'branzino': 7,
#  u'sesame seeds buns': 1,
#  u'pork shoulder boston butt': 26,
#  u'tarragon vinegar': 11,
#  u'tricolor quinoa': 2,
#  u'bocconcini': 17,
#  u'masa': 25,
#  u'mini cucumbers': 2,
#  u'coconut syrup': 1,
#  u'chocolate cake mix': 3,
#  u'curly leaf spinach': 1,
#  u'petite peas': 5,
#  u'dri basil leaves, crush': 2,
#  u'Louisiana Hot Sauce': 14,
#  u'Gourmet Garden Parsley': 1,
#  u'puff paste': 1,
#  u'sesame paste': 18,
#  u'Chinese rose wine': 5,
#  u'ginger paste': 119,
#  u'salted roast peanuts': 33,
#  u'veal shoulder': 3,
#  u'dressing': 63,
#  u'thai black glutinous rice': 1,
#  u'nori': 96,
#  u'ditalini pasta': 17,
#  u'sour salt': 1,
#  u'cr\xe8me de cassis': 5,
#  u'canned salmon': 1,
#  u'baton': 7,
#  u'shrimp and crab boil seasoning': 9,
#  u'minced meat': 4,
#  u'Italian seasoned panko bread crumbs': 1,
#  u'chip plain tortilla': 10,
#  u'slider rolls': 1,
#  u'refrigerated crescent rolls': 25,
#  u"tony chachere's seasoning": 1,
#  u'jambalaya mix': 3,
#  u'gluten-free oat': 1,
#  u'eating apple': 2,
#  u'prosciutto': 284,
#  u'great northern beans': 50,
#  u'crema mexican': 29,
#  u'shanghai bok choy': 2,
#  u'hot red pepper flakes': 171,
#  u'clam juice': 92,
#  u'quick-cooking barley': 4,
#  u'baking mix': 18,
#  u'thai chile': 223,
#  u'whole wheat dough': 2,
#  u'pandan essence': 1,
#  u'fresh mint': 416,
#  u'huckleberries': 1,
#  u'Italian herbs': 8,
#  u'cajun-creole seasoning mix': 2,
#  u'jumbo macaroni shells': 1,
#  u'burgundy': 4,
#  u'black bass': 3,
#  u'puff pastry sheets': 9,
#  u'lady apples': 1,
#  u'thin rice stick noodles': 2,
#  u'Boston lettuce': 27,
#  u'brie cheese': 37,
#  u'knorr rice side   cheddar broccoli': 2,
#  u'chicken stock cubes': 46,
#  u'boneless center cut pork chops': 4,
#  u'vanilla soy milk': 2,
#  u'skim milk': 81,
#  u'abura age': 4,
#  u'veal breast': 2,
#  u'anchovy filets': 4,
#  u'miniature semisweet chocolate chips': 5,
#  u'low-fat cheese': 3,
#  u'boneless beef roast': 4,
#  u'sherbet': 1,
#  u'asian rice noodles': 2,
#  u'crab claws': 2,
#  u'light molasses': 20,
#  u'chestnut mushrooms': 11,
#  u'pork baby back ribs': 26,
#  u'char siu sauce': 3,
#  u'pears': 97,
#  u'pollock': 2,
#  u'unsalted dry roast peanuts': 58,
#  u'fat free beef broth': 7,
#  u'boneless pork shoulder roast': 10,
#  u'Kikkoman Less Sodium Soy Sauce': 1,
#  u'beef boneless meat stew': 2,
#  u'king salmon': 1,
#  u'malt': 1,
#  u'chocolate fudge ice cream': 1,
#  u'dried currants': 95,
#  u'Holland House White Wine Vinegar': 1,
#  u'soft taco size flour tortillas': 5,
#  u'corned beef': 32,
#  u'baby potatoes': 19,
#  u'guajillo chile powder': 3,
#  u'tenderloin roast': 4,
#  u'frozen blueberries': 18,
#  u'chocolate milk': 1,
#  u'small red potato': 79,
#  u'key lime juice': 31,
#  u'shredded zucchini': 15,
#  u'beef stew': 1,
#  u'vanilla sugar': 9,
#  u'cholesterol free egg substitute': 1,
#  u'reduced fat provolone cheese': 2,
#  u'cheese cubes': 5,
#  u'shahi jeera': 20,
#  u'green olives': 177,
#  u'boneless skinless chicken breasts': 1111,
#  u'sliced olives': 11,
#  u'potato flakes': 8,
#  u'asian dressing': 1,
#  u'patis': 9,
#  u'chocolate covered coffee beans': 3,
#  u"Best Food's Mayonnaise with Lime Juice": 2,
#  u'tentacles': 13,
#  u'arrow root': 1,
#  u'crumb crust': 2,
#  u'ajinomoto': 3,
#  u'lavash': 2,
#  u'mousse': 1,
#  u'chicken bouillon': 77,
#  u'pitted date': 49,
#  u'turkey ham': 1,
#  u'lean ground meat': 13,
#  u'rotel tomatoes': 26,
#  u'baby beets': 1,
#  u'fresh orange': 3,
#  u'gingersnap cookies': 4,
#  u'kirby cucumbers': 26,
#  u'sauce': 458,
#  u'hot chili oil': 14,
#  u'wasabe': 1,
#  u'lower sodium chicken broth': 71,
#  u'ground red pepper': 538,
#  u'porridge oats': 5,
#  u'wasabi': 32,
#  u'roasted chestnuts': 6,
#  u'stuffing mix': 8,
#  u'rice bran oil': 4,
#  u'33% less sodium smoked fully cooked ham': 1,
#  u'flaxseed': 5,
#  u'truffle puree': 1,
#  u'ground thyme': 36,
#  u'crispy rice cereal': 3,
#  u'boneless pork loin': 62,
#  u'Alexia Waffle Fries': 1,
#  u'whole wheat couscous': 8,
#  u'dried rice noodles': 42,
#  u'awase miso': 1,
#  u'fried rice': 4,
#  u'thai jasmine rice': 5,
#  u'cranberry sauce': 5,
#  u'Ragu Sauce': 1,
#  u'vegetarian refried beans': 11,
#  u'cooked shrimp': 92,
#  u'yellow peas': 2,
#  u'mora chiles': 1,
#  u'apricot preserves': 29,
#  u'mushroom soy sauce': 15,
#  u'andouille sausage links': 8,
#  u'chile bean paste': 5,
#  u'blackberry jam': 6,
#  u'baby leaf lettuce': 5,
#  u'branzino fillets': 1,
#  u'lemon zest': 249,
#  u'mixed seafood': 3,
#  u'lady fingers': 2,
#  u'sesame salt': 2,
#  u'agave tequila': 1,
#  u'dark corn syrup': 41,
#  u'veal kidneys': 1,
#  u'champagne vinegar': 29,
#  u'low sodium chicken stock': 40,
#  u'refrigerated seamless crescent dough': 1,
#  u'rapid rise yeast': 16,
#  u'minced ginger': 198,
#  u'whole wheat thin italian pizza crust': 1,
#  u'hots': 1,
#  u'garlic oil': 9,
#  u'chopped nuts': 14,
#  u'mcintosh apples': 3,
#  u'garlic chives': 25,
#  u'vidalia': 4,
#  u'fresh thyme leaves': 190,
#  u'barbecue seasoning': 1,
#  u'grated coconut': 74,
#  u'poppy seeds': 70,
#  u'flaked': 5,
#  u'palm oil': 12,
#  u'pasta rotel': 2,
#  u'ragu old world style sweet tomato basil pasta sauc': 2,
#  u'tortellini': 20,
#  u'black turtle beans': 4,
#  u'filet mignon': 11,
#  u'skinless snapper fillets': 1,
#  u'yellow bell pepper': 291,
#  u'pita bread rounds': 21,
#  u'whole wheat spaghetti': 29,
#  u'spaghetti': 342,
#  u'mian': 1,
#  u'bow-tie pasta': 103,
#  u'wieners': 1,
#  u'sweet pickle': 11,
#  u'cream cheese with chives': 2,
#  ...}
